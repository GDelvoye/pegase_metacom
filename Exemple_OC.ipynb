# %%
import random as rd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
sns.set()
import package_thierache.classes as cl
import package_thierache.wf_discret as wf
import sauvegarde as svg
import matrice as mat
import analyse_resultat as ana
import routine as rt

# %%
#Fenetre OC calibrée
m_OC = svg.recuperation('OC_base_fit_ok_5e6')

# %%
m_OC.plot_territoire()

# %%
m_OC.plot_diversite()
# Out:
# Obs VS Sim: 7176
